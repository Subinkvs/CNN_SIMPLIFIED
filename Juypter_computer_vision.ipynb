# %%
import cv2

# Load the pre-trained face detection model
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)

# Start webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    # Convert to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.3,
        minNeighbors=5
    )

    # Draw rectangle around faces
    for (x, y, w, h) in faces:
        cv2.rectangle(
            frame,
            (x, y),
            (x+w, y+h),
            (255, 0, 0),
            2
        )

    # Display output
    cv2.imshow("Face Detection Demo", frame)

    # Press q to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt

# Load image (replace with your image path)
image_path = "image_path/image.jpg"
img = cv2.imread(image_path) # Reads image → converts to numbers

# Check if image is loaded
if img is None:
    print("Error: Image not found!")
else:
    # Convert BGR (OpenCV format) to RGB (Matplotlib format)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Display using matplotlib
    plt.imshow(img_rgb)
    plt.title("Loaded Image")
    plt.axis('off')  # Hide axis
    plt.show() # Converts numbers → shows image

# %%
import cv2
import matplotlib.pyplot as plt

# Load image (replace with your image path)
image_path = "image_path/image.jpg"
img = cv2.imread(image_path) # Reads image → converts to numbers

# Check if image is loaded
if img is None:
    print("Error: Image not found!")
else:
    # Convert BGR (OpenCV format) to RGB (Matplotlib format)
    resized = cv2.resize(img, (300, 300))
    img_rgb = cv2.cvtColor(resized, cv2.COLOR_BGR2RGB)

    # Display using matplotlib
    plt.imshow(img_rgb)
    plt.title("Loaded Image")
    plt.axis('off')  # Hide axis
    plt.show() # Converts numbers → shows image

# %%
import cv2
import matplotlib.pyplot as plt

image_path = "image_path/image.jpg"
img = cv2.imread(image_path)

if img is None:
    print("Error: Image not found!")
else:
    # Flip horizontally
    flipped = cv2.flip(img, 1)
    

    # Convert to RGB for display
    flipped_rgb = cv2.cvtColor(flipped, cv2.COLOR_BGR2RGB)

    plt.imshow(flipped_rgb)
    plt.title("Horizontally Flipped Image")
    plt.axis('off')
    plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

image_path = "image_path/image.jpg"
img = cv2.imread(image_path)

if img is None:
    print("Error: Image not found!")
else:
    # Flip horizontally
    flipped = cv2.flip(img, 0)

    # Convert to RGB for display
    flipped_rgb = cv2.cvtColor(flipped, cv2.COLOR_BGR2RGB)

    plt.imshow(flipped_rgb)
    plt.title("Vertical Flipped Image")
    plt.axis('off')
    plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

image_path = "image_path/image.jpg"
img = cv2.imread(image_path)

if img is None:
    print("Error: Image not found!")
else:
    # Convert to grayscale (important for edge detection)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Apply Canny Edge Detection
    edges = cv2.Canny(gray, 100, 200)

    # Display
    plt.imshow(edges, cmap='gray')
    plt.title("Edge Detection (Canny)")
    plt.axis('off')
    plt.show()

# %%
print(img.shape)
# Out:
# (2160, 3840, 3)

# %%
# Visualize an image

cv2.imshow('image', img)
cv2.waitKey(5000)
# Out:
# -1

# %%
import cv2
import os


video_path = 'video.mp4'
video = cv2.VideoCapture(video_path)


ret = True

while ret:
    ret, frame = video.read()

    if ret:
        cv2.imshow('frame', frame)
        cv2.waitKey(40) # 25 FPS  1000/25 = 40

video.release()
cv2.destroyAllWindows()

# %%
import cv2

webcam = cv2.VideoCapture(0)

ret = True

while True:
    ret, frame = webcam.read()


    cv2.imshow('frame', frame)
    if cv2.waitKey(16) & 0xFF == ord('q'):
        break

webcam.release()
cv2.destroyAllWindows()

# %%
import cv2

image_path = 'image_path/image.jpg'
img = cv2.imread(image_path)

print(img.shape)

while True:
    cv2.imshow('image', img)

    # Wait 1 ms and check for key press
    key = cv2.waitKey(1) & 0xFF

    if key == ord('q'):  # if 'q' is pressed
        break


cv2.destroyAllWindows()
# Out:
# (2160, 3840, 3)

# %%
import cv2

img = cv2.imread('image_path/image.jpg')

# Resize (width, height)
img_resized = cv2.resize(img, (1000, 600))

cv2.imshow('Image', img_resized)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cropped_img = img_resized[200:400, 150:300]
cv2.imshow('cropped_img', cropped_img)
cv2.waitKey(0)
# Out:
# -1

# %%
import cv2

image = cv2.imread('image_path/parrot_image.jpg')

cv2.imshow('Image', image)
cv2.waitKey(0)

new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2.imshow('new_image', new_image)
cv2.waitKey(0)
# Out:
# -1
